# %% [markdown]
# # TriTrust-Gait release inspection
# This notebook reads existing files; it is not a record of the historical paper experiments. Synthetic test results and reported manuscript aggregates remain separate. Run from the package root.

# %%
from pathlib import Path
import csv, json
root = Path.cwd()
assert (root / "README.md").exists()
print((root / "docs/EVIDENCE_AUDIT.md").read_text())

# %%
reported = list(csv.DictReader((root / "reported/reported_development_metrics.csv").open()))
reported

# %% [markdown]
# The preceding numbers are supplied aggregates, not recomputed metrics. The following rows come from actual synthetic fixture execution.

# %%
fixture = list(csv.DictReader((root / "supplementary/executed_fixture_metrics.csv").open()))
fixture

# %%
json.loads((root / "validation/executed/artifact_verification.json").read_text())

# %% [markdown]
# To run the complete new synthetic verification: `python scripts/run_all.py --out validation/fresh`. Read `docs/DATA_FORMAT.md` and `docs/PROTOCOLS.md` before any research run.
